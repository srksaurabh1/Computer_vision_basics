# %% [markdown]
# Name: Saurabh S. Ramteke
# Roll No: 21-27-19
# M.Tech: Data Science

# %% [markdown]
# Aim: To study and implement image edge detection techniques using python for processing image data

# %% [markdown]
# Edge Detection deals with the contours of an image usually denoted as an outline of a specific object in an image.

# %% [markdown]
# The goal of an edge detector is to enhance the connected gradients in an image, which may take the form
# of an edge, contour, line, or some connected set of edges. Many edge detectors are simply implemented as
# kernel operations, or convolutions

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r"C:\Users\saura\Desktop\Ongoing\Notes\01.LAB_ass\Computer_vision_basics\Images\sloth.jpg")
image2 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(10,10))
plt.imshow(image2)

# %%
hsv = cv2.cvtColor(image2, cv2.COLOR_RGB2HSV)
plt.imshow(hsv)

# %%
lower_red = np.array([30,  150, 50])
upper_red = np.array([255, 255, 180])

mask = cv2.inRange(hsv, lower_red, upper_red)
res = cv2.bitwise_and(frame, frame, mask=mask)

plt.imshow(frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11812/806372245.py in <module>
#       3
#       4 mask = cv2.inRange(hsv, lower_red, upper_red)
# ----> 5 res = cv2.bitwise_and(frame, frame, mask=mask)
#       6
#       7 plt.imshow(frame)
#
# NameError: name 'frame' is not defined

# %%
edges = cv2.Canny(frame,100,200)
plt.imshow(edges)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11812/2712115524.py in <module>
# ----> 1 edges = cv2.Canny(frame,100,200)
#       2 plt.imshow(edges)
#
# NameError: name 'frame' is not defined
